# %%
import pandas as pd #импортваме библиотека

# %%
pew_data = pd.read_csv("data_tidying/pew.csv") # четем csv файл и го записваме като променлива
pew_data.head() # показваме първит 5  записа
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
pew_data = pd.melt(pew_data, id_vars = "religion", var_name = "salary", value_name = "people")
pew_data.head()
# Out:
#              religion salary  people
# 0            Agnostic  <$10k      27
# 1             Atheist  <$10k      12
# 2            Buddhist  <$10k      27
# 3            Catholic  <$10k     418
# 4  Don’t know/refused  <$10k      15

# %%
pew_data.shape
# Out:
# (180, 3)

# %%
# Messy to Tidy Data (2)

# %%
tb = pd.read_csv("data_tidying/tb.csv") # четем csv файл
tb.head() # показваме първите 5 реда
# Out:
#   iso2  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564 ...  f04  \
# 0   AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN ...  NaN
# 1   AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN ...  NaN
# 2   AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN ...  NaN
# 3   AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN ...  NaN
# 4   AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
tb.columns #проверяваме всички имена на колоните
# Out:
# Index(['iso2', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
tb.iso2.unique() # проверяваме всички уникални стойности в колона iso2
# Out:
# array(['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AN', 'AO', 'AR', 'AS',
#        'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI',
#        'BJ', 'BM', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA',
#        'CD', 'CF', 'CG', 'CH', 'CI', 'CK', 'CL', 'CM', 'CN', 'CO', 'CR',
#        'CU', 'CV', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC',
#        'EE', 'EG', 'ER', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB',
#        'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GU', 'GW', 'GY',
#        'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IR',
#        'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN',
#        'KP', 'KR', 'KW', 'KY', 'KZ', 'LA', 'LB', 'LC', 'LK', 'LR', 'LS',
#        'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK',
#        'ML', 'MM', 'MN', 'MO', 'MP', 'MR', 'MS', 'MT', 'MU', 'MV', 'MW',
#        'MX', 'MY', 'MZ', nan, 'NC', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP',
# ...

# %%
tb.tail() # показва последните 5 реда от таблицата
# Out:
#      iso2  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564 ...   \
# 5764   ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0 ...
# 5765   ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0 ...
# 5766   ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0 ...
# 5767   ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0 ...
# 5768   ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0 ...
#
#       f04   f514   f014   f1524   f2534   f3544  f4554  f5564    f65   fu
# 5764  NaN    NaN  225.0  1140.0  2858.0  1565.0  622.0  214.0  111.0  NaN
# 5765  NaN    NaN  269.0  1136.0  2242.0  1255.0  578.0  193.0  603.0  NaN
# 5766  NaN    NaN  237.0  1020.0  2424.0  1355.0  632.0  230.0   96.0  NaN
# 5767  7.0  178.0  185.0   739.0  3311.0     0.0  553.0  213.0   90.0  NaN
# 5768  NaN    NaN  145.0   840.0     0.0  2890.0  467.0  174.0  105.0  0.0
#
# [5 rows x 22 columns]

# %%
tb = pd.melt(tb, id_vars = ["iso2", "year"], value_name = "cases", var_name = "sex_and_age")

# %%
tb.sex_and_age
# Out:
# 0         m04
# 1         m04
# 2         m04
# 3         m04
# 4         m04
# 5         m04
# 6         m04
# 7         m04
# 8         m04
# 9         m04
# 10        m04
# 11        m04
# 12        m04
# 13        m04
# 14        m04
# 15        m04
# 16        m04
# 17        m04
# 18        m04
# 19        m04
# 20        m04
# 21        m04
# 22        m04
# 23        m04
# 24        m04
# 25        m04
# 26        m04
# 27        m04
# 28        m04
# 29        m04
#          ...
# 115350     fu
# 115351     fu
# 115352     fu
# 115353     fu
# 115354     fu
# 115355     fu
# 115356     fu
# 115357     fu
# 115358     fu
# 115359     fu
# 115360     fu
# 115361     fu
# 115362     fu
# 115363     fu
# 115364     fu
# 115365     fu
# 115366     fu
# 115367     fu
# 115368     fu
# 115369     fu
# 115370     fu
# 115371     fu
# 115372     fu
# 115373     fu
# 115374     fu
# 115375     fu
# 115376     fu
# 115377     fu
# 115378     fu
# 115379     fu
# ...
