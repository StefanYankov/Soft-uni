# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 

from skimage.io import imread, imshow

# %%
tiger_image = imread("http://www.abc.net.au/news/image/7318414-3x2-940x627.jpg")

# %%
tiger_image.shape
# Out:
# (627, 940, 3)

# %%
imshow(tiger_image)
# Out:
# C:\Users\Stefano\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Stefano\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
tiger_image[0, 0, :] # first pixel
#       red green blue
# Out:
# array([50, 60, 51], dtype=uint8)

# %%
tiger_image[:, :, 0]
# Out:
# array([[ 50,  49,  48, ...,  94,  98, 112],
#        [ 49,  49,  48, ...,  90, 101, 112],
#        [ 48,  48,  49, ...,  92, 107, 112],
#        ...,
#        [ 41,  39,  38, ...,   0,   0,   0],
#        [ 39,  38,  37, ...,   0,   0,   0],
#        [ 39,  38,  37, ...,   0,   0,   0]], dtype=uint8)

# %%
burger_image = imread("http://lab.students.softuni.bg/assets/courseware/v1/692dbe85139f974150d80f57becfe093/asset-v1:SoftUni+DS101+June-2018+type@asset+block/hamburger.jpg")

# %%
imshow(burger_image)
# Out:
# C:\Users\Stefano\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Stefano\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
burger_image.shape
# Out:
# (417, 626, 3)

# %%
red = burger_image[:, :, 0]
green = burger_image[:, :, 1]
blue = burger_image[:, :, 2]

# %%
plt.hist(red.ravel(), bins = 256, color = "red")
plt.hist(green.ravel(), bins = 256, color = "green")
plt.hist(blue.ravel(), bins = 256, color = "blue")
plt.ylim(0, 20000)
plt.show()

# %%
burger_mean = np.mean(burger_image, axis = 2)

# %%
imshow(burger_mean)
# Out:
# C:\Users\Stefano\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\Stefano\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "
# C:\Users\Stefano\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
table = burger_image[:, :, 2]

# %%
np.mean(burger_image)
# Out:
# 70.31709967489267
